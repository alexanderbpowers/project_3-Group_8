# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '/Users/alexanderpowers/Documents/GitHub/Project_3/Brazil Data/north.csv'
stations = pd.read_csv(file_path)

# %% [markdown]
# # Investigate Data

# %%
stations = stations.rename(columns={"index":"ID",
    "first date":"first_date",
    "station_code":"station_id"})
stations.head()
# Out:
#                        station region state station_id  first_date  height  \
# 0                    QUEIMADAS     NE    BA       A436  2008-05-23   315.0
# 1                        MACAU     NE    RN       A317  2007-01-06    32.0
# 2  SAQUAREMA - SAMPAIO CORREIA     SE    RJ       A667  2019-01-01    26.0
# 3        SANTANA DO LIVRAMENTO      S    RS       A804  2001-11-22   328.0
# 4                   VILA VELHA     SE    ES       A634  2017-02-15    25.0
#
#    longitude   latitude
# 0 -39.616944 -10.984645
# 1 -36.573056  -5.151111
# 2 -42.608889 -22.871111
# 3 -55.401389 -30.750556
# 4 -40.403889 -20.466944

# %% [markdown]
# # Clean Data

# %%
# select stations
chosen_station = ['A111', 'A134', 'A051', 'A216', 'A247', 'A113', 'A119', 'A939',
       'A055', 'A018', 'A215', 'A240', 'A123', 'A104', 'A050', 'A202',
       'A250', 'A101', 'A102', 'A233', 'A235', 'A044', 'A048', 'A234']
stations = stations[stations.region == 'N']
stations = stations[stations['station_id'].isin(chosen_station)]
stations
# Out:
#                        station region state station_id  first_date  height  \
# 17                        APUI      N    AM       A113  2008-07-19  160.00
# 32                        PIUM      N    TO       A051  2016-04-06  161.00
# 70                  MANACAPURU      N    AM       A119  2008-04-10   55.00
# 79                   CASTANHAL      N    PA       A202  2003-01-24   65.00
# 86          S. G. DA CACHOEIRA      N    AM       A134  2011-08-31   90.00
# 110       SANTA FE DO ARAGUAIA      N    TO       A048  2016-07-30  171.00
# 134                   SANTAREM      N    PA       A250  2015-09-02  137.00
# 193                   RIO SONO      N    TO       A050  2016-08-03  291.00
# 221                     MANAUS      N    AM       A101  2000-05-09   61.25
# 225        SANTANA DO ARAGUAIA      N    PA       A233  2008-05-30  176.75
# 267                     MARABA      N    PA       A240  2009-06-25  116.58
# ...

# %%
stations_final = stations[stations["station_id"].isin(chosen_station)]
cols = ['station_id', 'station', 'region', 'state', 'first_date', 'height', 'longitude', 'latitude']
stations_final = stations_final[cols]

# %%
stations_final.reset_index(drop=True, inplace=True)
stations_final.head()
# Out:
#   station_id             station region state  first_date  height  longitude  \
# 0       A113                APUI      N    AM  2008-07-19   160.0 -59.888561
# 1       A051                PIUM      N    TO  2016-04-06   161.0 -49.629444
# 2       A119          MANACAPURU      N    AM  2008-04-10    55.0 -60.628333
# 3       A202           CASTANHAL      N    PA  2003-01-24    65.0 -47.930833
# 4       A134  S. G. DA CACHOEIRA      N    AM  2011-08-31    90.0 -67.061111
#
#     latitude
# 0  -7.205475
# 1 -10.476944
# 2  -3.294722
# 3  -1.300833
# 4  -0.125000

# %%
from sqlalchemy import create_engine
postgres_uri = 'postgresql://irkqykpauqvpzm:b6a2bf95436de0394e29cb2c7b916b56f18fe92c6a3f5ac85638d94c4a93b081@ec2-107-22-122-106.compute-1.amazonaws.com:5432/d5tqri7nt2h2k0'

engine = create_engine(postgres_uri)
stations_final.to_sql("stations", con=engine, if_exists='append')
