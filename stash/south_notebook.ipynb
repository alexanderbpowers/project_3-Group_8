# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
south = pd.read_csv("south.csv")

# %%
south.head()

# %%
max_date = south['Data'].max()
min_date = south['Data'].min()

stations = south['station_code'].unique()

print(min_date, max_date)
print(stations)

start_date = '2020-04-30'

# %%
renamed_columns_en = ['date','hour','total precipitation (mm)','pressao atmosferica ao nivel da estacao (mb)','atmospheric pressure max. in the previous hour (mb)','atmospheric pressure min. in the previous hour (mb)','radiation (kj/m2)','air temperature - dry bulb (°c)','dew point temperature (°c)','max. temperature in the previous hour (°c)','min. temperature in the previous hour (°c)','dew temperature max. in the previous hour (°c)','dew temperature min. in the previous hour (°c)','relative humidity max. in the previous hour (%)','relative humidity min. in the previous hour (%)','air relative humidity (%)','wind direction (° (gr))','wind rajada maxima (m/s)','wind speed (m/s)','region','state','station','station_code','latitude','longitude','height']

def process_raw(df):
    """
    ! drop index
    ! rename the columns
    ! combine hour and date columns -> transform to date_time
    ! append columns data from all stations to keep the data granularity
    ! remove not useful columns
    ! return table 
    """
    df.drop(['index'],inplace=True, axis=1)
    df.columns = renamed_columns_en
    df['date_time'] = pd.to_datetime(df['date'] + ' ' +  df['hour'])
    df.drop(['date','hour','pressao atmosferica ao nivel da estacao (mb)','atmospheric pressure max. in the previous hour (mb)','atmospheric pressure min. in the previous hour (mb)','radiation (kj/m2)','air temperature - dry bulb (°c)','dew point temperature (°c)', 'dew temperature max. in the previous hour (°c)','dew temperature min. in the previous hour (°c)','air relative humidity (%)','wind direction (° (gr))','wind rajada maxima (m/s)'], inplace=True, axis=1)

    # station_codes = list(df.station_code.unique())
    # df_models = by_code(df,station_codes[0])
    # if len(station_codes)>1:
    #     for i in station_codes[1:]:
    #         df_temp = by_code(df,i)
    #         df_models = pd.concat([df_models,df_temp],axis=1)
    return df

# def by_code(df, station_code):
#     """
#     ! function that filters the dataframe by station_code and rename the columns by the status code
#     """
#     df_station = None
#     df_station = df[df['station_code'] == station_code]
#     df_station.index = df_station.iloc[:,-1]
#     df_station.drop(['station_code','date_time'],axis=1,inplace=True)
#     df_station.columns = list(map(lambda x: station_code+'_'+x, df_station.columns))
#     return df_station

# def clean_na(df, na_value = -9999):
#     """ 
#     ! replace Na from dataset
#     """
#     df = df.replace(to_replace=na_value,value=np.NaN)
#     df = df[df.iloc[:,1].first_valid_index():]
#     df = df.fillna(method='ffill')
#     return df

def make_dataset(stations, start_date, df):
    """
    ! filter raw data from date and stations code
    ! process data
    ! clean na
    """
    df = df[df['Data'] >= start_date]
    df = df[df['station_code'].apply(lambda x: x in stations)]
    df = process_raw(df)
    # df = clean_na(df)
    return df.reset_index()

# %%
south['relative humidity min. in the previous hour (%)']==-9999]

# %%
south_Clean = make_dataset(stations,'2018-04-03', south)
south_Clean.info()

# %%
south_Clean = make_dataset(stations,'2018-04-03', south)
south_Clean

# the start_date variable I set up produces an empty table

# %%
# south_Clean.to_csv("2018_south.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
south = pd.read_csv("2018_south.csv")
south
# Out:
#          Unnamed: 0     index  total precipitation (mm)  \
# 0                 0   7576632                       0.0
# 1                 1   7576633                       0.0
# 2                 2   7576634                       0.0
# 3                 3   7576635                       0.0
# 4                 4   7576636                       0.2
# ...             ...       ...                       ...
# 2509075     2509075  10284883                       0.0
# 2509076     2509076  10284884                       0.0
# 2509077     2509077  10284885                       0.0
# 2509078     2509078  10284886                       0.0
# 2509079     2509079  10284887                       0.0
#
#          max. temperature in the previous hour (°c)  \
# 0                                              16.8
# 1                                              15.3
# 2                                              14.2
# 3                                              13.7
# 4                                              13.1
# ...                                             ...
# 2509075                                        21.6
# 2509076                                        20.9
# 2509077                                        20.1
# 2509078                                        18.5
# 2509079                                        17.5
#
#          min. temperature in the previous hour (°c)  \
# 0                                              15.0
# 1                                              13.9
# 2                                              13.2
# 3                                              12.3
# 4                                              12.3
# ...                                             ...
# 2509075                                        20.7
# 2509076                                        20.1
# 2509077                                        18.4
# 2509078                                        17.5
# 2509079                                        14.8
#
#          relative humidity max. in the previous hour (%)  \
# 0                                                     96
# 1                                                     96
# 2                                                     97
# 3                                                     97
# 4                                                     97
# ...                                                  ...
# 2509075                                               40
# 2509076                                               40
# 2509077                                               47
# 2509078                                               51
# 2509079                                               62
#
#          relative humidity min. in the previous hour (%)  wind speed (m/s)  \
# 0                                                     93               0.1
# 1                                                     96               0.2
# 2                                                     96               0.0
# 3                                                     97               0.0
# 4                                                     97               0.0
# ...                                                  ...               ...
# 2509075                                               36               4.1
# 2509076                                               36               3.2
# 2509077                                               40               2.1
# 2509078                                               46               2.1
# 2509079                                               51               3.1
#
#         region state           station station_code   latitude  longitude  \
# 0            S    PR  GENERAL CARNEIRO         A875 -26.398611 -51.354444
# 1            S    PR  GENERAL CARNEIRO         A875 -26.398611 -51.354444
# 2            S    PR  GENERAL CARNEIRO         A875 -26.398611 -51.354444
# 3            S    PR  GENERAL CARNEIRO         A875 -26.398611 -51.354444
# 4            S    PR  GENERAL CARNEIRO         A875 -26.398611 -51.354444
# ...        ...   ...               ...          ...        ...        ...
# 2509075      S    RS    LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509076      S    RS    LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509077      S    RS    LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509078      S    RS    LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509079      S    RS    LAGOA VERMELHA         A844 -28.222381 -51.512845
#
#           height            date_time
# 0        1018.00  2018-11-01 23:00:00
# 1        1018.00  2018-11-02 00:00:00
# 2        1018.00  2018-11-02 01:00:00
# 3        1018.00  2018-11-02 02:00:00
# 4        1018.00  2018-11-02 03:00:00
# ...          ...                  ...
# 2509075   833.83  2021-04-30 19:00:00
# 2509076   833.83  2021-04-30 20:00:00
# 2509077   833.83  2021-04-30 21:00:00
# 2509078   833.83  2021-04-30 22:00:00
# 2509079   833.83  2021-04-30 23:00:00
#
# [2509080 rows x 16 columns]

# %%
south[south['date_time']>'2020-01-01']
# Out:
#          Unnamed: 0     index  total precipitation (mm)  \
# 1412664     1412664   9188472                       0.0
# 1412665     1412665   9188473                       0.0
# 1412666     1412666   9188474                       0.0
# 1412667     1412667   9188475                       0.0
# 1412668     1412668   9188476                       0.0
# ...             ...       ...                       ...
# 2509075     2509075  10284883                       0.0
# 2509076     2509076  10284884                       0.0
# 2509077     2509077  10284885                       0.0
# 2509078     2509078  10284886                       0.0
# 2509079     2509079  10284887                       0.0
#
#          max. temperature in the previous hour (°c)  \
# 1412664                                        16.2
# 1412665                                        16.1
# 1412666                                        16.3
# 1412667                                        17.1
# 1412668                                        18.0
# ...                                             ...
# 2509075                                        21.6
# 2509076                                        20.9
# 2509077                                        20.1
# 2509078                                        18.5
# 2509079                                        17.5
#
#          min. temperature in the previous hour (°c)  \
# 1412664                                        15.8
# 1412665                                        15.8
# 1412666                                        16.1
# 1412667                                        16.3
# 1412668                                        17.0
# ...                                             ...
# 2509075                                        20.7
# 2509076                                        20.1
# 2509077                                        18.4
# 2509078                                        17.5
# 2509079                                        14.8
#
#          relative humidity max. in the previous hour (%)  \
# 1412664                                            -9999
# 1412665                                            -9999
# 1412666                                            -9999
# 1412667                                            -9999
# 1412668                                            -9999
# ...                                                  ...
# 2509075                                               40
# 2509076                                               40
# 2509077                                               47
# 2509078                                               51
# 2509079                                               62
#
#          relative humidity min. in the previous hour (%)  wind speed (m/s)  \
# 1412664                                            -9999               1.8
# 1412665                                            -9999               2.3
# 1412666                                            -9999               1.3
# 1412667                                            -9999               3.5
# 1412668                                            -9999               3.1
# ...                                                  ...               ...
# 2509075                                               36               4.1
# 2509076                                               36               3.2
# 2509077                                               40               2.1
# 2509078                                               46               2.1
# 2509079                                               51               3.1
#
#         region state         station station_code   latitude  longitude  \
# 1412664      S    SC       ARARANGUA         A867 -28.931353 -49.497920
# 1412665      S    SC       ARARANGUA         A867 -28.931353 -49.497920
# 1412666      S    SC       ARARANGUA         A867 -28.931353 -49.497920
# 1412667      S    SC       ARARANGUA         A867 -28.931353 -49.497920
# 1412668      S    SC       ARARANGUA         A867 -28.931353 -49.497920
# ...        ...   ...             ...          ...        ...        ...
# 2509075      S    RS  LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509076      S    RS  LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509077      S    RS  LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509078      S    RS  LAGOA VERMELHA         A844 -28.222381 -51.512845
# 2509079      S    RS  LAGOA VERMELHA         A844 -28.222381 -51.512845
#
#          height            date_time
# 1412664    2.00  2020-09-11 08:00:00
# 1412665    2.00  2020-09-11 09:00:00
# 1412666    2.00  2020-09-11 10:00:00
# 1412667    2.00  2020-09-11 11:00:00
# 1412668    2.00  2020-09-11 12:00:00
# ...         ...                  ...
# 2509075  833.83  2021-04-30 19:00:00
# 2509076  833.83  2021-04-30 20:00:00
# 2509077  833.83  2021-04-30 21:00:00
# 2509078  833.83  2021-04-30 22:00:00
# 2509079  833.83  2021-04-30 23:00:00
#
# [1096416 rows x 16 columns]

# %%
# south.drop(south[south['relative humidity min. in the previous hour (%)']==-9999])


south[south['relative humidity min. in the previous hour (%)']==-9999]

# %%
# Get indexes where name column has value john
indexNames = south[south['relative humidity min. in the previous hour (%)']==-9999].index
# Delete these row indexes from dataFrame
south.drop(indexNames , inplace=True)


index2 = south[south['relative humidity max. in the previous hour (%)']==-9999].index
# Delete these row indexes from dataFrame
south.drop(index2 , inplace=True)
south

# %%
index3 = south[south['min. temperature in the previous hour (°c)']==-9999].index
# Delete these row indexes from dataFrame
south.drop(index3 , inplace=True)

index4 = south[south['max. temperature in the previous hour (°c)'] == -9999].index
# Delete these row indexes from dataFrame
south.drop(index4 , inplace=True)

index5 = south[south['total precipitation (mm)'] == -9999].index
south.drop(index5 , inplace=True)

index6 = south[south['wind speed (m/s)'] == -9999].index
south.drop(index6 , inplace=True)
south

# %%
# Checking the -9999 columns were removed
# south[south['max. temperature in the previous hour (°c)'] == -9999]
# south[south['max. temperature in the previous hour (°c)'] == -9999]
# south[south['total precipitation (mm)'] == -9999]
# south[south['wind speed (m/s)'] == -9999]
# south[south['relative humidity min. in the previous hour (%)']==-9999]
south[south['relative humidity max. in the previous hour (%)']==-9999]

# %%
south_2020 = south[south['date_time']>'2020-01-01']

# %%
# Created a new csv from 2020 onward 
# south_2020.to_csv("south2020_onward.csv")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
south2020_onward = pd.read_csv("south2020_onward.csv")
south2020_onward
